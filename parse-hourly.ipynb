# %%
from utz import *
from numpy import dtype
from tabula import read_pdf

# %%
year = 2022
last_month = None
n_jobs = 4
overwrite = False

# %%
if year == 2022 and last_month is None:
    last_month = 10  # 2022 data only committed here through October

# %%
stations = [
    'Christopher St.',
    '9th Street',
    '14th Street',
    '23rd Street',
    '33rd Street',
    'WTC',
    'Newark',
    'Harrison',
    'Journal Square',
    'Grove Street',
    'Exchange Place',
    'Newport',
    'Hoboken',
    'System-wide',
]
title = 1
contents = 2
ytd = 3
num_stations = len(stations)
section_pages = num_stations + 1  # title page
def month_page_range(month):
    start = 4 + month * section_pages
    end = start + num_stations
    return start, end

print(' '.join([ f'[{", ".join(map(str, month_page_range(month)))})' for month in range(1, 13) ]))
# Out:
# [19, 33) [34, 48) [49, 63) [64, 78) [79, 93) [94, 108) [109, 123) [124, 138) [139, 153) [154, 168) [169, 183) [184, 198)

# %%
station_offsets = { station: idx for idx, station in enumerate(stations) }
station_offsets
# Out:
# {'Christopher St.': 0,
#  '9th Street': 1,
#  '14th Street': 2,
#  '23rd Street': 3,
#  '33rd Street': 4,
#  'WTC': 5,
#  'Newark': 6,
#  'Harrison': 7,
#  'Journal Square': 8,
#  'Grove Street': 9,
#  'Exchange Place': 10,
#  'Newport': 11,
#  'Hoboken': 12,
#  'System-wide': 13}

# %%
template_path = 'templates/2022-PATH-hourly-Ridership-Report.tabula-template.json'
with open(template_path, 'r') as f:
    rects = json.load(f)
rects
# Out:
# [{'page': 19,
#   'extraction_method': 'guess',
#   'x1': 0.495,
#   'x2': 780.615,
#   'y1': 126.225,
#   'y2': 558.855,
#   'width': 780.12,
#   'height': 432.63},
#  {'page': 19,
#   'extraction_method': 'guess',
#   'x1': 257.895,
#   'x2': 535.095,
#   'y1': 14.355,
#   'y2': 77.715,
#   'width': 277.2,
#   'height': 63.36},
#  {'page': 19,
#   'extraction_method': 'guess',
#   'x1': 83.655,
#   'x2': 205.425,
#   'y1': 98.505,
#   'y2': 121.275,
#   'width': 121.77,
#   'height': 22.77}]

# %%
based_on_regex = '\(Based on (?P<month>\w+) (?P<year>\d{4}) Turnstile Count\)'
cross_honor_regex = '\(Cross[‐\-]honor (?:Entry )?Count not Included\)'

def clean(s):
    """Some years have "‐" (ord("‐") == 8028) instead of "-" (ord("-") == 45) in various titles/messages."""
    return s.replace('‐', '-')

def read_station_month_hours_tables(year, month, station):
    station_offset = station_offsets[station]
    pdf = f'data/{year}-PATH-hourly-Ridership-Report.pdf'
    start, _ = month_page_range(month)
    pg = start + station_offset
    month_name = to_dt('%d-%02d' % (year, month)).strftime('%B')
    print(f'Reading {pdf}, pg. {pg}: {month_name}, {station}')
    tables = [
        read_pdf(
            pdf,
            pages=pg,
            area=[ rect[k] for k in [ 'y1', 'x1', 'y2', 'x2', ] ],
            pandas_options={'header': None},
        )
        for rect in rects
    ]
    return tables

def to_hour(r):
    hour, AM = r['hour'], r['am'] == 'AM'
    return (0 if hour == 12 else hour) + (0 if AM else 12)

def parse_station_month_hours_tables(year, month, station):
    [hrs], [header], [actual_station] = read_station_month_hours_tables(year, month, station)
    [[actual_station]] = actual_station.values
    actual_station = clean(actual_station)  # "System-wide" can have either dash character
    if actual_station != station:
        raise RuntimeError(f"Parsed station {actual_station} != {station}")

    [[title], [based_on_msg], [cross_msg]] = header.values
    if clean(title) != 'PATH - Average Hourly Entry and Exit Counts by Station':
        raise RuntimeError(f'Unexpected title: "{title}"')

    m = fullmatch(based_on_regex, based_on_msg)
    if not m:
        raise RuntimeError(f'Unrecognized "based on" message: "{based_on_msg}"')
    parsed_year = int(m['year'])
    if year != parsed_year:
        raise RuntimeError(f"Parsed year {parsed_year} != {year}")
    parsed_month = m['month']
    month_name = to_dt('%d-%02d' % (year, month)).strftime('%B')
    if parsed_month != month_name:
        raise RuntimeError(f"Parsed month {parsed_month} != {month}")

    if not fullmatch(cross_honor_regex, cross_msg):
        raise RuntimeError(f'Unexpected cross-honor message: "{cross_msg}"')

    hrs = hrs.dropna(axis=1, how='all')
    headers = (hrs.iloc[0].fillna('') + ' ' + hrs.iloc[1]).str.strip()
    hrs = hrs.copy().iloc[2:]
    hrs = hrs.dropna(axis=1, how='all')
    headers = headers.dropna()
    hrs.columns = headers
    hrs['Year'] = year
    hrs['Month'] = month
    hrs['Station'] = station
    hrs = hrs[['Year', 'Month', 'Station'] + headers.tolist()]
    for k in hrs.columns[4:]:
        col = hrs[k]
        dt = col.dtype
        if dt == dtype('O'):
            hrs[k] = hrs[k].str.replace(',', '').astype(int)
        elif dt == dtype('float64'):
            hrs[k] = hrs[k].astype(int)
        elif dt == dtype('int64'):
            pass
        else:
            raise RuntimeError(f'Unexpected dtype, col {k}: {dt}')

    total_rows = hrs.Hour == 'Total'
    totals = hrs[total_rows]
    hrs = hrs[~total_rows]

    Hour = hrs.Hour.str.extract('(?P<hour>\d\d?):00:00 (?P<am>AM|PM)').astype({ 'hour': int }).apply(to_hour, axis=1)
    hrs['Hour'] = Hour

    system_wide_rows = hrs.Station == 'System-wide'
    system_wide = hrs[system_wide_rows]
    hrs = hrs[~system_wide_rows]

    return hrs, totals, system_wide

def read_month_hours_stations(year, month, n_jobs=None, concat=True):
    if n_jobs:
        parallel = Parallel(n_jobs=n_jobs)
        fn = delayed(parse_station_month_hours_tables)
        rvs = parallel(
            fn(year, month, station)
            for station in stations
        )
    else:
        rvs = [
            parse_station_month_hours_tables(year, month, station)
            for station in stations
        ]
    if concat:
        return [ pd.concat(dfs) for dfs in zip(*rvs) ]
    else:
        return dfs

def read_year_hours_stations(year, last_month=None, n_jobs=None, concat=True):
    rvs = [
        read_month_hours_stations(year, month, n_jobs=n_jobs)
        for month in range(1, 13 if last_month is None else (last_month + 1))
    ]
    if concat:
        return [ pd.concat(dfs) for dfs in zip(*rvs) ]
    else:
        return rvs

# %%
# %%time
suffixes = ['', '-total', '-system']
base = f'data/{year}-hourly'
paths = [ f'{base}{suffix}.pqt' for suffix in suffixes ]
extant = list(filter(exists, paths))

if extant and overwrite:
    print(f'Overwriting {", ".join(extant)}')

hrs, totals, system_wide = None, None, None
if extant != paths or overwrite:
    dfs = read_year_hours_stations(year, last_month=last_month, n_jobs=n_jobs)
    for df, path in zip(dfs, paths):
        print(f'Writing {path}')
        df.to_parquet(path, index=False)
    hrs, totals, system_wide = dfs

hrs
# Out:
# Writing data/2022-hourly_2022.pqt
# Writing data/2022-hourly-total_2022.pqt
# Writing data/2022-hourly-system_2022.pqt
# CPU times: user 186 ms, sys: 58.5 ms, total: 245 ms
# Wall time: 1min 31s

# %%
totals

# %%
system_wide
# Out:
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 22: January, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 26: January, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 30: January, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 34: February, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 39: February, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 42: February, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 47: February, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 50: March, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 53: March, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 57: March, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 61: March, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 65: April, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 68: April, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 72: April, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 76: April, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 80: May, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 83: May, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 90: May, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 97: June, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 99: June, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 102: June, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 106: June, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 110: July, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 113: July, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 117: July, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 122: July, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 126: August, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 129: August, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 133: August, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 136: August, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 141: September, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 145: September, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 149: September, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 19: January, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 25: January, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 28: January, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 32: January, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 36: February, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 40: February, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 44: February, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 49: March, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 54: March, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 59: March, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 64: April, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 71: April, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 74: April, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 79: May, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 84: May, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 89: May, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 92: May, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 95: June, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 101: June, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 104: June, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 109: July, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 115: July, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 120: July, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 124: August, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 128: August, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 132: August, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 137: August, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 140: September, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 146: September, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 150: September, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 21: January, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 24: January, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 29: January, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 37: February, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 41: February, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 45: February, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 52: March, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 55: March, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 60: March, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 62: March, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 67: April, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 70: April, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 75: April, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 82: May, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 85: May, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 87: May, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 91: May, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 96: June, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 100: June, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 105: June, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 111: July, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 116: July, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 119: July, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 127: August, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 131: August, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 135: August, Newport
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 142: September, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 143: September, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 148: September, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 151: September, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 20: January, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 23: January, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 27: January, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 31: January, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 35: February, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 38: February, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 43: February, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 46: February, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 51: March, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 56: March, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 58: March, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 66: April, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 69: April, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 73: April, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 77: April, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 81: May, 14th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 86: May, Harrison
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 88: May, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 94: June, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 98: June, 33rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 103: June, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 107: June, System-wide
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 112: July, 23rd Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 114: July, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 118: July, Grove Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 121: July, Hoboken
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 125: August, 9th Street
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 130: August, Newark
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 134: August, Exchange Place
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 139: September, Christopher St.
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 144: September, WTC
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 147: September, Journal Square
# Reading data/2022-PATH-hourly-Ridership-Report.pdf, pg. 152: September, System-wide
