# %%
from utz import *

# %%
df = concat([ read_parquet(f'{year}.pqt') for year in range(2012, 2023) ])
df
# Out:
#                                 avg daily  avg weekday   avg sat  avg sun  \
# month      station
# 2012-01-01 Christopher Street    112187.0       4256.0    2708.0   2433.0
#            9thStreet             126682.0       4483.0    3695.0   3436.0
#            14thStreet            228483.0       8768.0    5346.0   4730.0
#            23rdStreet            197597.0       8345.0    2924.0   2563.0
#            33rdStreet            886167.0      34797.0   17350.0  16716.0
# ...                                   ...          ...       ...      ...
# 2022-09-01 Exchange Place        215744.0       8554.0    4923.0   3391.0
#            Pavonia/ Newport      259470.0      10132.0    6340.0   4357.0
#            Hoboken               389679.0      15242.0    9854.0   6288.0
#            NEW JERSEY SUBTOTAL  2229280.0      86797.0   55621.0  37561.0
#            MONTHLY TOTAL        4068090.0     157982.0  100592.0  71504.0
#
# ...

# %%
df = df.reset_index()
df
# Out:
#           month              station  avg daily  avg weekday   avg sat  \
# 0    2012-01-01   Christopher Street   112187.0       4256.0    2708.0
# 1    2012-01-01            9thStreet   126682.0       4483.0    3695.0
# 2    2012-01-01           14thStreet   228483.0       8768.0    5346.0
# 3    2012-01-01           23rdStreet   197597.0       8345.0    2924.0
# 4    2012-01-01           33rdStreet   886167.0      34797.0   17350.0
# ...         ...                  ...        ...          ...       ...
# 4228 2022-09-01       Exchange Place   215744.0       8554.0    4923.0
# 4229 2022-09-01     Pavonia/ Newport   259470.0      10132.0    6340.0
# 4230 2022-09-01              Hoboken   389679.0      15242.0    9854.0
# 4231 2022-09-01  NEW JERSEY SUBTOTAL  2229280.0      86797.0   55621.0
# 4232 2022-09-01        MONTHLY TOTAL  4068090.0     157982.0  100592.0
#
#       avg sun  avg holiday     total  total weekday  total sat  total sun  \
# ...

# %%
import plotly.express as px

# %%
fig = px.bar(
    df[~df.station.str.contains('TOTAL')],
    x='month', y='avg weekday', color='station',
    title='Average weekday PATH ridership',
    labels={
        'station': 'Station',
        'avg weekday': 'Avg Weekday Ridership',
        'month': 'Month',
    }
).update_layout(
    title_x=0.5,
)
fig.write_image('weekdays.png', width=1200, height=600,)
fig
# Out:
# <div>                            <div id="ff62531b-e5d5-4279-b18b-5f8291a72605" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff62531b-e5d5-4279-b18b-5f8291a72605")) {                    Plotly.newPlot(                        "ff62531b-e5d5-4279-b18b-5f8291a72605",                        [{"alignmentgroup":"True","hovertemplate":"Station=Christopher Street<br>Month=%{x}<br>Avg Weekday Ridership=%{y}<extra></extra>","legendgroup":"Christopher Street","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Christopher Street","offsetgroup":"Christopher Street","orientation":"v","showlegend":true,"textposition":"auto","x":["2012-01-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:
# ...
